# %% [markdown]
# 1.  https://www.amazon.com/dp/B0CWXNS552
# 2.

# %%
# !pip install apify
# Out:
# Collecting apify
#   Downloading apify-2.5.0-py3-none-any.whl.metadata (21 kB)
# Collecting apify-client>=1.9.2 (from apify)
#   Downloading apify_client-1.10.0-py3-none-any.whl.metadata (17 kB)
# Collecting apify-shared>=1.3.0 (from apify)
#   Downloading apify_shared-1.4.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting crawlee~=0.6.0 (from apify)
#   Downloading crawlee-0.6.9-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: cryptography>=42.0.0 in /usr/local/lib/python3.11/dist-packages (from apify) (43.0.3)
# Requirement already satisfied: httpx>=0.27.0 in /usr/local/lib/python3.11/dist-packages (from apify) (0.28.1)
# Collecting lazy-object-proxy>=1.10.0 (from apify)
#   Downloading lazy_object_proxy-1.11.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: more-itertools>=10.2.0 in /usr/local/lib/python3.11/dist-packages (from apify) (10.7.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.11/dist-packages (from apify) (4.13.2)
# Requirement already satisfied: websockets>=14.0 in /usr/local/lib/python3.11/dist-packages (from apify) (15.0.1)
# Collecting apify-fingerprint-datapoints>=0.0.2 (from crawlee~=0.6.0->apify)
#   Downloading apify_fingerprint_datapoints-0.0.2-py3-none-any.whl.metadata (14 kB)
# Collecting browserforge>=1.2.3 (from crawlee~=0.6.0->apify)
#   Downloading browserforge-1.2.3-py3-none-any.whl.metadata (28 kB)
# Requirement already satisfied: cachetools>=5.5.0 in /usr/local/lib/python3.11/dist-packages (from crawlee~=0.6.0->apify) (5.5.2)
# Collecting certifi<=2025.1.31 (from crawlee~=0.6.0->apify)
#   Downloading certifi-2025.1.31-py3-none-any.whl.metadata (2.5 kB)
# Collecting colorama>=0.4.0 (from crawlee~=0.6.0->apify)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting eval-type-backport>=0.2.0 (from crawlee~=0.6.0->apify)
#   Downloading eval_type_backport-0.2.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting protego>=0.4.0 (from crawlee~=0.6.0->apify)
#   Downloading Protego-0.4.0-py2.py3-none-any.whl.metadata (6.2 kB)
# Collecting psutil>=6.0.0 (from crawlee~=0.6.0->apify)
#   Downloading psutil-7.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Requirement already satisfied: pydantic!=2.10.0,!=2.10.1,!=2.10.2,>=2.8.0 in /usr/local/lib/python3.11/dist-packages (from crawlee~=0.6.0->apify) (2.11.3)
# Collecting pydantic-settings<2.7.0,>=2.2.0 (from crawlee~=0.6.0->apify)
#   Downloading pydantic_settings-2.6.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting pyee>=9.0.0 (from crawlee~=0.6.0->apify)
#   Downloading pyee-13.0.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting sortedcollections>=2.1.0 (from crawlee~=0.6.0->apify)
#   Downloading sortedcollections-2.1.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: sortedcontainers>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from crawlee~=0.6.0->apify) (2.4.0)
# Collecting tldextract>=5.1.0 (from crawlee~=0.6.0->apify)
#   Downloading tldextract-5.3.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: yarl>=1.18.0 in /usr/local/lib/python3.11/dist-packages (from crawlee~=0.6.0->apify) (1.20.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography>=42.0.0->apify) (1.17.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx>=0.27.0->apify) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.27.0->apify) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx>=0.27.0->apify) (3.10)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.27.0->apify) (0.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from browserforge>=1.2.3->crawlee~=0.6.0->apify) (8.1.8)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography>=42.0.0->apify) (2.22)
# Collecting brotli (from httpx[brotli,http2,zstd]>=0.27.0->crawlee~=0.6.0->apify)
#   Downloading Brotli-1.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.5 kB)
# Requirement already satisfied: h2<5,>=3 in /usr/local/lib/python3.11/dist-packages (from httpx[brotli,http2,zstd]>=0.27.0->crawlee~=0.6.0->apify) (4.2.0)
# Requirement already satisfied: zstandard>=0.18.0 in /usr/local/lib/python3.11/dist-packages (from httpx[brotli,http2,zstd]>=0.27.0->crawlee~=0.6.0->apify) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=2.10.0,!=2.10.1,!=2.10.2,>=2.8.0->crawlee~=0.6.0->apify) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /usr/local/lib/python3.11/dist-packages (from pydantic!=2.10.0,!=2.10.1,!=2.10.2,>=2.8.0->crawlee~=0.6.0->apify) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=2.10.0,!=2.10.1,!=2.10.2,>=2.8.0->crawlee~=0.6.0->apify) (0.4.0)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<2.7.0,>=2.2.0->crawlee~=0.6.0->apify)
#   Downloading python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: requests>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from tldextract>=5.1.0->crawlee~=0.6.0->apify) (2.32.3)
# Collecting requests-file>=1.4 (from tldextract>=5.1.0->crawlee~=0.6.0->apify)
#   Downloading requests_file-2.1.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: filelock>=3.0.8 in /usr/local/lib/python3.11/dist-packages (from tldextract>=5.1.0->crawlee~=0.6.0->apify) (3.18.0)
# Requirement already satisfied: multidict>=4.0 in /usr/local/lib/python3.11/dist-packages (from yarl>=1.18.0->crawlee~=0.6.0->apify) (6.4.3)
# Requirement already satisfied: propcache>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from yarl>=1.18.0->crawlee~=0.6.0->apify) (0.3.1)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx>=0.27.0->apify) (1.3.1)
# Requirement already satisfied: hyperframe<7,>=6.1 in /usr/local/lib/python3.11/dist-packages (from h2<5,>=3->httpx[brotli,http2,zstd]>=0.27.0->crawlee~=0.6.0->apify) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /usr/local/lib/python3.11/dist-packages (from h2<5,>=3->httpx[brotli,http2,zstd]>=0.27.0->crawlee~=0.6.0->apify) (4.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.1.0->tldextract>=5.1.0->crawlee~=0.6.0->apify) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.1.0->tldextract>=5.1.0->crawlee~=0.6.0->apify) (2.4.0)
# Downloading apify-2.5.0-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 3.6 MB/s eta 0:00:00
# Downloading apify_client-1.10.0-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.7/77.7 kB 4.1 MB/s eta 0:00:00
# Downloading apify_shared-1.4.1-py3-none-any.whl (12 kB)
# Downloading crawlee-0.6.9-py3-none-any.whl (259 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.6/259.6 kB 13.7 MB/s eta 0:00:00
# Downloading lazy_object_proxy-1.11.0-py3-none-any.whl (16 kB)
# Downloading apify_fingerprint_datapoints-0.0.2-py3-none-any.whl (836 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 836.2/836.2 kB 29.8 MB/s eta 0:00:00
# Downloading browserforge-1.2.3-py3-none-any.whl (39 kB)
# Downloading certifi-2025.1.31-py3-none-any.whl (166 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.4/166.4 kB 9.4 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading eval_type_backport-0.2.2-py3-none-any.whl (5.8 kB)
# Downloading Protego-0.4.0-py2.py3-none-any.whl (8.6 kB)
# Downloading psutil-7.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (277 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.0/278.0 kB 15.0 MB/s eta 0:00:00
# Downloading pydantic_settings-2.6.1-py3-none-any.whl (28 kB)
# Downloading pyee-13.0.0-py3-none-any.whl (15 kB)
# Downloading sortedcollections-2.1.0-py3-none-any.whl (9.5 kB)
# Downloading tldextract-5.3.0-py3-none-any.whl (107 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.4/107.4 kB 6.1 MB/s eta 0:00:00
# Downloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Downloading requests_file-2.1.0-py2.py3-none-any.whl (4.2 kB)
# Downloading Brotli-1.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 66.7 MB/s eta 0:00:00
# Installing collected packages: brotli, sortedcollections, python-dotenv, pyee, psutil, protego, lazy-object-proxy, eval-type-backport, colorama, certifi, browserforge, apify-shared, apify-fingerprint-datapoints, requests-file, pydantic-settings, tldextract, apify-client, crawlee, apify
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.9.5
#     Uninstalling psutil-5.9.5:
#       Successfully uninstalled psutil-5.9.5
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2025.4.26
#     Uninstalling certifi-2025.4.26:
#       Successfully uninstalled certifi-2025.4.26
# Successfully installed apify-2.5.0 apify-client-1.10.0 apify-fingerprint-datapoints-0.0.2 apify-shared-1.4.1 brotli-1.1.0 browserforge-1.2.3 certifi-2025.1.31 colorama-0.4.6 crawlee-0.6.9 eval-type-backport-0.2.2 lazy-object-proxy-1.11.0 protego-0.4.0 psutil-7.0.0 pydantic-settings-2.6.1 pyee-13.0.0 python-dotenv-1.1.0 requests-file-2.1.0 sortedcollections-2.1.0 tldextract-5.3.0

# %%
from apify_client import ApifyClient
import pandas as pd

# Initialize the ApifyClient with your API token
client = ApifyClient("apify_api_0CHseitfItBsI9Rt3GJeN8Hkm6wX4a4yHEXq")

# Prepare the Actor input
run_input = {
    "productUrls": [{ "url": "https://www.amazon.com/dp/B0CWXNS552"}],
    "maxReviews": 100,
    "reviewMediaTypes": [],
    "includeGdprSensitive": False,
    "reviewsUseProductVariantFilter": False,
    "reviewsEnqueueProductVariants": False,
    "proxyCountry": "AUTO_SELECT_PROXY_COUNTRY",
    "scrapeProductDetails": False,
    "reviewsAlwaysSaveCategoryData": False,
    "scrapeQuickProductReviews": True,
    "deduplicateRedirectedAsins": True,
}

# Run the Actor and wait for it to finish
run = client.actor("R8WeJwLuzLZ6g4Bkk").call(run_input=run_input)

# Fetch Actor results and store them in a list
items = []
for item in client.dataset(run["defaultDatasetId"]).iterate_items():
    items.append(item)

# Convert the list of items to a DataFrame
import pandas as pd
df = pd.DataFrame(items)
df.to_csv('amazon_reviews.csv', index=False)
df=pd.read_csv("/content/amazon_reviews.csv")
df.head()
# Out:
#                                        userId  \
# 0  amzn1.account.AFMXEG4GE5X2AKEMEZDQH76K4OMQ
# 1  amzn1.account.AFYW3PW3XYGHUY3FVUJ2PG6L5RAQ
# 2  amzn1.account.AGSO32B7MD6PJPO3VDIJ4YBKHXNQ
# 3  amzn1.account.AFEHTG46OCX3QGYQ33YV6QS2NX5Q
# 4  amzn1.account.AGFASHLLI5XOL7OQZX7EFXZJ5RFA
#
#                                      userProfileLink  ratingScore  \
# 0  https://www.amazon.com/gp/profile/amzn1.accoun...            5
# 1  https://www.amazon.com/gp/profile/amzn1.accoun...            5
# 2  https://www.amazon.com/gp/profile/amzn1.accoun...            5
# 3  https://www.amazon.com/gp/profile/amzn1.accoun...            5
# 4  https://www.amazon.com/gp/profile/amzn1.accoun...            5
#
#                                          reviewTitle  \
# 0       Apple AirTag – A Game Changer for Lost Keys!
# 1                                   Travel necessity
# 2  So useful for all sorts of things! You can hel...
# 3             Work Well For Tracking Important Items
# 4                   Peace of mind in a tiny package!
#
#                                    reviewDescription        date  position  \
# 0  The Apple AirTag has been an absolute game cha...  2025-03-27         1
# 1  Apple AirTags are the BEST! Great for tracking...  2025-04-25         2
# 2  I have quite a few of these! They work so well...  2025-04-15         3
# 3  Have several Apple AirTags in use and tied to ...  2025-04-13         4
# 4  The Apple AirTag is an absolute lifesaver! I b...  2025-04-03         5
#
#                                         reviewedIn        reviewId  \
# 0  Reviewed in the United States on March 27, 2025  R35G4YHRRYCC1P
# 1  Reviewed in the United States on April 25, 2025  R1OROWRCLU8ZS9
# 2  Reviewed in the United States on April 15, 2025   R2ZMMX7O7WZG8
# 3  Reviewed in the United States on April 13, 2025   RVYHOFSHT6W4U
# 4   Reviewed in the United States on April 3, 2025  R14ZDNZ0BSYX4P
#
#                                            reviewUrl  ... variantAsin  \
# 0  https://www.amazon.com/gp/customer-reviews/R35...  ...  B0CWXNS552
# 1  https://www.amazon.com/gp/customer-reviews/R1O...  ...  B0CWXNS552
# 2  https://www.amazon.com/gp/customer-reviews/R2Z...  ...  B0CWXNS552
# 3  https://www.amazon.com/gp/customer-reviews/RVY...  ...  B0CWXNS552
# 4  https://www.amazon.com/gp/customer-reviews/R14...  ...  B0CWXNS552
#
#   reviewCategoryUrl  totalCategoryRatings  totalCategoryReviews  \
# 0               NaN                   NaN                   NaN
# 1               NaN                   NaN                   NaN
# 2               NaN                   NaN                   NaN
# 3               NaN                   NaN                   NaN
# 4               NaN                   NaN                   NaN
#
#   filterByRating filterByKeyword                                 input  \
# 0       allStars             NaN  https://www.amazon.com/dp/B0CWXNS552
# 1       allStars             NaN  https://www.amazon.com/dp/B0CWXNS552
# 2       allStars             NaN  https://www.amazon.com/dp/B0CWXNS552
# 3       allStars             NaN  https://www.amazon.com/dp/B0CWXNS552
# 4       allStars             NaN  https://www.amazon.com/dp/B0CWXNS552
#
#          country countryCode                             product
# 0  United States         NaN  {'price': None, 'listPrice': None}
# 1  United States         NaN  {'price': None, 'listPrice': None}
# 2  United States         NaN  {'price': None, 'listPrice': None}
# 3  United States         NaN  {'price': None, 'listPrice': None}
# 4  United States         NaN  {'price': None, 'listPrice': None}
#
# [5 rows x 29 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 29 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   userId                               6 non-null      object
#  1   userProfileLink                      6 non-null      object
#  2   ratingScore                          6 non-null      int64
#  3   reviewTitle                          6 non-null      object
#  4   reviewDescription                    6 non-null      object
#  5   date                                 6 non-null      object
#  6   position                             6 non-null      int64
#  7   reviewedIn                           6 non-null      object
#  8   reviewId                             6 non-null      object
#  9   reviewUrl                            6 non-null      object
#  10  reviewImages                         6 non-null      object
#  11  reviewReaction                       6 non-null      object
#  12  isVerified                           6 non-null      bool
#  13  isAmazonVine                         6 non-null      bool
#  14  variant                              6 non-null      object
#  15  variantAttributes                    6 non-null      object
#  16  isProductPageReviewFromOtherCountry  6 non-null      bool
#  17  productAsin                          6 non-null      object
#  18  productOriginalAsin                  6 non-null      object
#  19  variantAsin                          6 non-null      object
#  20  reviewCategoryUrl                    0 non-null      float64
#  21  totalCategoryRatings                 0 non-null      float64
#  22  totalCategoryReviews                 0 non-null      float64
#  23  filterByRating                       6 non-null      object
#  24  filterByKeyword                      0 non-null      float64
#  25  input                                6 non-null      object
#  26  country                              6 non-null      object
#  27  countryCode                          0 non-null      float64
#  28  product                              6 non-null      object
# dtypes: bool(3), float64(5), int64(2), object(19)
# memory usage: 1.4+ KB
